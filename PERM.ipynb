# %% [markdown]
# # PERM Enumerating Gene Orders

# %% [markdown]
# A permutation of length n is an ordering of the positive integers {1,2,…,n}. For example, π=(5,3,2,1,4) is a permutation of length 5
#
#
#
# **Given:** A positive integer n≤7
#
#
#
# **Return:** The total number of permutations of length n, followed by a list of all such permutations (in any order).

# %%
fin = open("rosalind_perm.txt")
for line in fin:
    n=int(line.strip())

my_list=[i+1 for i in range(n)]
        
my_list
# Out:
# [1, 2, 3, 4, 5]

# %%
import itertools
perm_list=list(itertools.permutations(my_list))
perm_list
# Out:
# [(1, 2, 3, 4, 5),
#  (1, 2, 3, 5, 4),
#  (1, 2, 4, 3, 5),
#  (1, 2, 4, 5, 3),
#  (1, 2, 5, 3, 4),
#  (1, 2, 5, 4, 3),
#  (1, 3, 2, 4, 5),
#  (1, 3, 2, 5, 4),
#  (1, 3, 4, 2, 5),
#  (1, 3, 4, 5, 2),
#  (1, 3, 5, 2, 4),
#  (1, 3, 5, 4, 2),
#  (1, 4, 2, 3, 5),
#  (1, 4, 2, 5, 3),
#  (1, 4, 3, 2, 5),
#  (1, 4, 3, 5, 2),
#  (1, 4, 5, 2, 3),
#  (1, 4, 5, 3, 2),
#  (1, 5, 2, 3, 4),
#  (1, 5, 2, 4, 3),
#  (1, 5, 3, 2, 4),
#  (1, 5, 3, 4, 2),
#  (1, 5, 4, 2, 3),
#  (1, 5, 4, 3, 2),
#  (2, 1, 3, 4, 5),
#  (2, 1, 3, 5, 4),
#  (2, 1, 4, 3, 5),
#  (2, 1, 4, 5, 3),
#  (2, 1, 5, 3, 4),
#  (2, 1, 5, 4, 3),
#  (2, 3, 1, 4, 5),
#  (2, 3, 1, 5, 4),
#  (2, 3, 4, 1, 5),
#  (2, 3, 4, 5, 1),
#  (2, 3, 5, 1, 4),
#  (2, 3, 5, 4, 1),
#  (2, 4, 1, 3, 5),
#  (2, 4, 1, 5, 3),
#  (2, 4, 3, 1, 5),
#  (2, 4, 3, 5, 1),
#  (2, 4, 5, 1, 3),
#  (2, 4, 5, 3, 1),
#  (2, 5, 1, 3, 4),
#  (2, 5, 1, 4, 3),
#  (2, 5, 3, 1, 4),
#  (2, 5, 3, 4, 1),
#  (2, 5, 4, 1, 3),
#  (2, 5, 4, 3, 1),
#  (3, 1, 2, 4, 5),
#  (3, 1, 2, 5, 4),
#  (3, 1, 4, 2, 5),
#  (3, 1, 4, 5, 2),
#  (3, 1, 5, 2, 4),
#  (3, 1, 5, 4, 2),
#  (3, 2, 1, 4, 5),
#  (3, 2, 1, 5, 4),
#  (3, 2, 4, 1, 5),
#  (3, 2, 4, 5, 1),
#  (3, 2, 5, 1, 4),
#  (3, 2, 5, 4, 1),
#  (3, 4, 1, 2, 5),
#  (3, 4, 1, 5, 2),
#  (3, 4, 2, 1, 5),
#  (3, 4, 2, 5, 1),
#  (3, 4, 5, 1, 2),
#  (3, 4, 5, 2, 1),
#  (3, 5, 1, 2, 4),
#  (3, 5, 1, 4, 2),
#  (3, 5, 2, 1, 4),
#  (3, 5, 2, 4, 1),
#  (3, 5, 4, 1, 2),
#  (3, 5, 4, 2, 1),
#  (4, 1, 2, 3, 5),
#  (4, 1, 2, 5, 3),
#  (4, 1, 3, 2, 5),
#  (4, 1, 3, 5, 2),
#  (4, 1, 5, 2, 3),
#  (4, 1, 5, 3, 2),
#  (4, 2, 1, 3, 5),
#  (4, 2, 1, 5, 3),
#  (4, 2, 3, 1, 5),
#  (4, 2, 3, 5, 1),
#  (4, 2, 5, 1, 3),
#  (4, 2, 5, 3, 1),
#  (4, 3, 1, 2, 5),
#  (4, 3, 1, 5, 2),
#  (4, 3, 2, 1, 5),
#  (4, 3, 2, 5, 1),
#  (4, 3, 5, 1, 2),
#  (4, 3, 5, 2, 1),
#  (4, 5, 1, 2, 3),
#  (4, 5, 1, 3, 2),
#  (4, 5, 2, 1, 3),
#  (4, 5, 2, 3, 1),
#  (4, 5, 3, 1, 2),
#  (4, 5, 3, 2, 1),
#  (5, 1, 2, 3, 4),
#  (5, 1, 2, 4, 3),
#  (5, 1, 3, 2, 4),
#  (5, 1, 3, 4, 2),
#  (5, 1, 4, 2, 3),
#  (5, 1, 4, 3, 2),
#  (5, 2, 1, 3, 4),
#  (5, 2, 1, 4, 3),
#  (5, 2, 3, 1, 4),
#  (5, 2, 3, 4, 1),
#  (5, 2, 4, 1, 3),
#  (5, 2, 4, 3, 1),
#  (5, 3, 1, 2, 4),
#  (5, 3, 1, 4, 2),
#  (5, 3, 2, 1, 4),
#  (5, 3, 2, 4, 1),
#  (5, 3, 4, 1, 2),
#  (5, 3, 4, 2, 1),
#  (5, 4, 1, 2, 3),
#  (5, 4, 1, 3, 2),
#  (5, 4, 2, 1, 3),
#  (5, 4, 2, 3, 1),
#  (5, 4, 3, 1, 2),
#  (5, 4, 3, 2, 1)]

# %%
print(len(perm_list))
for i in range(len(perm_list)):
    inner_set=perm_list[i]
    templist=[]
    for num in inner_set:
        templist.append(str(num))
    print(" ".join(templist))
# Out:
# 120
# 1 2 3 4 5
# 1 2 3 5 4
# 1 2 4 3 5
# 1 2 4 5 3
# 1 2 5 3 4
# 1 2 5 4 3
# 1 3 2 4 5
# 1 3 2 5 4
# 1 3 4 2 5
# 1 3 4 5 2
